# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Specify the URL
url = 'https://books.toscrape.com'  # Replace with your URL

# Make a request to the website
response = requests.get(url)
html_content = response.text

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find all titles (replace 'h2' with the appropriate tag you want to scrape)
titles = soup.find_all('head')
results = [title.text for title in titles]

# Create a DataFrame
df = pd.DataFrame(results, columns=['Title'])

# Display the DataFrame
print(df)
# Out:
#                                                Title
# 0  \n\n    All products | Books to Scrape - Sandb...

# %%
# !pip install requests beautifulsoup4 pandas matplotlib seaborn
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL of the website to scrape
url = 'http://books.toscrape.com/'

# Make a request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all book containers
    books = soup.select('.product_pod')

    # Lists to hold data
    titles = []
    prices = []

    # Loop through each book container and extract the title and price
    for book in books:
        title = book.h3.a['title']  # Get the title attribute
        price = book.find('p', class_='price_color').text  # Get the price
        titles.append(title)
        prices.append(price)

    # Convert prices to float
    prices = [float(price[1:]) for price in prices]  # Remove currency symbol and convert to float

    # Create a DataFrame with the extracted data
    df = pd.DataFrame({
        'Title': titles,
        'Price': prices
    })

    # Display the DataFrame
    print(df)

    # Display basic statistics
    print(df.describe())

    # Plot the distribution of book prices
    plt.figure(figsize=(12, 6))
    sns.histplot(df['Price'], bins=20, kde=True)
    plt.title('Distribution of Book Prices')
    plt.xlabel('Price ($)')
    plt.ylabel('Frequency')
    plt.show()
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-83f673dc39b8> in <cell line: 14>()
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # Remove currency symbol and convert to float
#      34
#      35     # Create a DataFrame with the extracted data
#
# <ipython-input-2-83f673dc39b8> in <listcomp>(.0)
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # Remove currency symbol and convert to float
#      34
#      35     # Create a DataFrame with the extracted data
#
# ValueError: could not convert string to float: '£51.77'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL of the website to scrape
url = 'http://books.toscrape.com/'

# Make a request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all book containers
    books = soup.select('.product_pod')

    # Lists to hold data
    titles = []
    prices = []

    # Loop through each book container and extract the title and price
    for book in books:
        title = book.h3.a['title']  # Get the title attribute
        price = book.find('p', class_='price_color').text  # Get the price
        titles.append(title)
        prices.append(price)

    # Convert prices to float
    prices = [float(price[1:]) for price in prices]  # Corrected line

    # Create a DataFrame with the extracted data
    df = pd.DataFrame({
        'Title': titles,
        'Price': prices
    })

    # Display the DataFrame
    print(df)

    # Display basic statistics
    print(df.describe())

    # Plot the distribution of book prices
    plt.figure(figsize=(12, 6))
    sns.histplot(df['Price'], bins=20, kde=True)
    plt.title('Distribution of Book Prices')
    plt.xlabel('Price ($)')
    plt.ylabel('Frequency')
    plt.show()
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8c09fab4a546> in <cell line: 14>()
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # Corrected line
#      34
#      35     # Create a DataFrame with the extracted data
#
# <ipython-input-4-8c09fab4a546> in <listcomp>(.0)
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # Corrected line
#      34
#      35     # Create a DataFrame with the extracted data
#
# ValueError: could not convert string to float: '£51.77'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL of the website to scrape
url = 'http://books.toscrape.com/'

# Make a request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all book containers
    books = soup.select('.product_pod')

    # Lists to hold data
    titles = []
    prices = []

    # Loop through each book container and extract the title and price
    for book in books:
        title = book.h3.a['title']  # Get the title attribute
        price = book.find('p', class_='price_color').text  # Get the price
        titles.append(title)
        prices.append(price)

    # Convert prices to float
    prices = [float(price[1:]) for price in prices]  # This line is corrected

    # Create a DataFrame with the extracted data
    df = pd.DataFrame({
        'Title': titles,
        'Price': prices
    })

    # Display the DataFrame
    print(df)

    # Display basic statistics
    print(df.describe())

    # Plot the distribution of book prices
    plt.figure(figsize=(12, 6))
    sns.histplot(df['Price'], bins=20, kde=True)
    plt.title('Distribution of Book Prices')
    plt.xlabel('Price ($)')
    plt.ylabel('Frequency')
    plt.show()
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-796a2cd6c4d6> in <cell line: 14>()
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # This line is corrected
#      34
#      35     # Create a DataFrame with the extracted data
#
# <ipython-input-5-796a2cd6c4d6> in <listcomp>(.0)
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # This line is corrected
#      34
#      35     # Create a DataFrame with the extracted data
#
# ValueError: could not convert string to float: '£51.77'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL of the website to scrape
url = 'http://books.toscrape.com/'

# Make a request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all book containers
    books = soup.select('.product_pod')

    # Lists to hold data
    titles = []
    prices = []

    # Loop through each book container and extract the title and price
    for book in books:
        title = book.h3.a['title']  # Get the title attribute
        price = book.find('p', class_='price_color').text  # Get the price
        titles.append(title)
        prices.append(price)

    # Convert prices to float
    prices = [float(price[1:]) for price in prices]  # Correctly slice and convert to float

    # Create a DataFrame with the extracted data
    df = pd.DataFrame({
        'Title': titles,
        'Price': prices
    })

    # Display the DataFrame
    print(df)

    # Display basic statistics
    print(df.describe())

    # Plot the distribution of book prices
    plt.figure(figsize=(12, 6))
    sns.histplot(df['Price'], bins=20, kde=True)
    plt.title('Distribution of Book Prices')
    plt.xlabel('Price ($)')
    plt.ylabel('Frequency')
    plt.show()
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-95a32f69a9e2> in <cell line: 14>()
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # Correctly slice and convert to float
#      34
#      35     # Create a DataFrame with the extracted data
#
# <ipython-input-6-95a32f69a9e2> in <listcomp>(.0)
#      31
#      32     # Convert prices to float
# ---> 33     prices = [float(price[1:]) for price in prices]  # Correctly slice and convert to float
#      34
#      35     # Create a DataFrame with the extracted data
#
# ValueError: could not convert string to float: '£51.77'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL of the website to scrape
url = 'http://books.toscrape.com/'

# Make a request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all book containers
    books = soup.select('.product_pod')

    # Lists to hold data
    titles = []
    prices = []

    # Loop through each book container and extract the title and price
    for book in books:
        title = book.h3.a['title']  # Get the title attribute
        price = book.find('p', class_='price_color').text  # Get the price
        titles.append(title)
        prices.append(price)

    # Convert prices to float, removing currency symbols and unexpected characters
    prices = [float(price.replace('£', '').replace(',', '').strip()) for price in prices]  # Simplified line

    # Create a DataFrame with the extracted data
    df = pd.DataFrame({
        'Title': titles,
        'Price': prices
    })

    # Display the DataFrame
    print(df)

    # Display basic statistics
    print(df.describe())

    # Plot the distribution of book prices
    plt.figure(figsize=(12, 6))
    sns.histplot(df['Price'], bins=20, kde=True)
    plt.title('Distribution of Book Prices')
    plt.xlabel('Price ($)')
    plt.ylabel('Frequency')
    plt.show()
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2320d45d85fd> in <cell line: 14>()
#      31
#      32     # Convert prices to float, removing currency symbols and unexpected characters
# ---> 33     prices = [float(price.replace('£', '').replace(',', '').strip()) for price in prices]  # Simplified line
#      34
#      35     # Create a DataFrame with the extracted data
#
# <ipython-input-9-2320d45d85fd> in <listcomp>(.0)
#      31
#      32     # Convert prices to float, removing currency symbols and unexpected characters
# ---> 33     prices = [float(price.replace('£', '').replace(',', '').strip()) for price in prices]  # Simplified line
#      34
#      35     # Create a DataFrame with the extracted data
#
# ValueError: could not convert string to float: 'Â51.77'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL of the website to scrape
url = 'http://books.toscrape.com/'

# Make a request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all book containers
    books = soup.select('.product_pod')

    # Lists to hold data
    titles = []
    prices = []

    # Loop through each book container and extract the title and price
    for book in books:
        title = book.h3.a['title']  # Get the title attribute
        price = book.find('p', class_='price_color').text  # Get the price
        titles.append(title)
        prices.append(price)

    # Print the list of prices to check their format
    print(prices)  # Add this line to inspect the prices

    # Convert prices to float, removing currency symbols and unexpected characters
    prices = [float(price.replace('£', '').replace(',', '').strip()) for price in prices]  # Updated line

    # Create a DataFrame with the extracted data
    df = pd.DataFrame({
        'Title': titles,
        'Price': prices
    })

    # Display the DataFrame
    print(df)

    # Display basic statistics
    print(df.describe())

    # Plot the distribution of book prices
    plt.figure(figsize=(12, 6))
    sns.histplot(df['Price'], bins=20, kde=True)
    plt.title('Distribution of Book Prices')
    plt.xlabel('Price ($)')
    plt.ylabel('Frequency')
    plt.show()
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ['Â£51.77', 'Â£53.74', 'Â£50.10', 'Â£47.82', 'Â£54.23', 'Â£22.65', 'Â£33.34', 'Â£17.93', 'Â£22.60', 'Â£52.15', 'Â£13.99', 'Â£20.66', 'Â£17.46', 'Â£52.29', 'Â£35.02', 'Â£57.25', 'Â£23.88', 'Â£37.59', 'Â£51.33', 'Â£45.17']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6a28d9264d2c> in <cell line: 14>()
#      34
#      35     # Convert prices to float, removing currency symbols and unexpected characters
# ---> 36     prices = [float(price.replace('£', '').replace(',', '').strip()) for price in prices]  # Updated line
#      37
#      38     # Create a DataFrame with the extracted data
#
# <ipython-input-10-6a28d9264d2c> in <listcomp>(.0)
#      34
#      35     # Convert prices to float, removing currency symbols and unexpected characters
# ---> 36     prices = [float(price.replace('£', '').replace(',', '').strip()) for price in prices]  # Updated line
#      37
#      38     # Create a DataFrame with the extracted data
#
# ValueError: could not convert string to float: 'Â51.77'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

def scrape_book_prices():
    # URL of the website to scrape
    url = 'http://books.toscrape.com/'

    try:
        # Make a request to the website
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Raise an exception for bad status codes

        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all book containers
        books = soup.select('.product_pod')

        # Lists to hold data
        titles = []
        prices = []

        # Loop through each book container and extract the title and price
        for book in books:
            try:
                title = book.h3.a['title']  # Get the title attribute
                price_elem = book.find('p', class_='price_color')

                if price_elem:
                    # Extract price using regex to remove all non-numeric characters except decimal point
                    price_str = price_elem.text
                    price = float(re.sub(r'[^\d.]', '', price_str))

                    titles.append(title)
                    prices.append(price)
            except (AttributeError, ValueError) as e:
                print(f"Error processing a book: {e}")

        # Create a DataFrame with the extracted data
        df = pd.DataFrame({
            'Title': titles,
            'Price': prices
        })

        # Display the DataFrame and statistics
        print(df)
        print("\nDataset Statistics:")
        print(df.describe())

        # Plot the distribution of book prices
        plt.figure(figsize=(12, 6))
        sns.histplot(df['Price'], bins=20, kde=True)
        plt.title('Distribution of Book Prices')
        plt.xlabel('Price (£)')
        plt.ylabel('Frequency')
        plt.show()

        return df

    except requests.RequestException as e:
        print(f"Error fetching the website: {e}")
        return None

# Run the scraping function
scrape_book_prices()
# Out:
#                                                 Title  Price
# 0                                A Light in the Attic  51.77
# 1                                  Tipping the Velvet  53.74
# 2                                          Soumission  50.10
# 3                                       Sharp Objects  47.82
# 4               Sapiens: A Brief History of Humankind  54.23
# 5                                     The Requiem Red  22.65
# 6   The Dirty Little Secrets of Getting Your Dream...  33.34
# 7   The Coming Woman: A Novel Based on the Life of...  17.93
# 8   The Boys in the Boat: Nine Americans and Their...  22.60
# 9                                     The Black Maria  52.15
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  13.99
# 11                              Shakespeare's Sonnets  20.66
# 12                                        Set Me Free  17.46
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  52.29
# 14                          Rip it Up and Start Again  35.02
# 15  Our Band Could Be Your Life: Scenes from the A...  57.25
# 16                                               Olio  23.88
# 17  Mesaerion: The Best Science Fiction Stories 18...  37.59
# 18                       Libertarianism for Beginners  51.33
# 19                            It's Only the Himalayas  45.17
#
# Dataset Statistics:
#            Price
# count  20.000000
# mean   38.048500
# std    15.135231
# min    13.990000
# 25%    22.637500
# 50%    41.380000
# 75%    51.865000
# max    57.250000
#                                                 Title  Price
# 0                                A Light in the Attic  51.77
# 1                                  Tipping the Velvet  53.74
# 2                                          Soumission  50.10
# 3                                       Sharp Objects  47.82
# 4               Sapiens: A Brief History of Humankind  54.23
# 5                                     The Requiem Red  22.65
# 6   The Dirty Little Secrets of Getting Your Dream...  33.34
# 7   The Coming Woman: A Novel Based on the Life of...  17.93
# 8   The Boys in the Boat: Nine Americans and Their...  22.60
# 9                                     The Black Maria  52.15
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  13.99
# 11                              Shakespeare's Sonnets  20.66
# 12                                        Set Me Free  17.46
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  52.29
# 14                          Rip it Up and Start Again  35.02
# 15  Our Band Could Be Your Life: Scenes from the A...  57.25
# 16                                               Olio  23.88
# 17  Mesaerion: The Best Science Fiction Stories 18...  37.59
# 18                       Libertarianism for Beginners  51.33
# 19                            It's Only the Himalayas  45.17
